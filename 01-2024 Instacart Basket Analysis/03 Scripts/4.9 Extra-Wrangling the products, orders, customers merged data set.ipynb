# %% [markdown]
# # Import libraries

# %%
# Importing libraries

import pandas as pd
import numpy as np
import os

# %%
# Define a path

path = r'C:\Users\junio\OneDrive\Career Foundry Project\01-2024 Instacart Basket Analysis'

# %%
# Importing the merged data set

all_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_customers_merged.pkl'))

# %% [markdown]
# # Investigate outliers

# %%
# Check to identify outliers
## If the maximum price anyone would pay in a supermarket were around $100,
## then anything above that amount could be considered an outlier.

all_combined.loc[all_combined['prices'] > 100]
# Out:
#           product_id                      product_name  aisle_id  \
# 23024          33664             2 % Reduced Fat  Milk        84
# 23025          33664             2 % Reduced Fat  Milk        84
# 23026          33664             2 % Reduced Fat  Milk        84
# 23027          33664             2 % Reduced Fat  Milk        84
# 28712          21553  Lowfat 2% Milkfat Cottage Cheese       108
# ...              ...                               ...       ...
# 32383871       21553  Lowfat 2% Milkfat Cottage Cheese       108
# 32383872       21553  Lowfat 2% Milkfat Cottage Cheese       108
# 32383873       21553  Lowfat 2% Milkfat Cottage Cheese       108
# 32396750       21553  Lowfat 2% Milkfat Cottage Cheese       108
# 32396768       21553  Lowfat 2% Milkfat Cottage Cheese       108
#
#           department_id   prices  departmend_id  order_id user_id  \
# 23024                16  99999.0             16   1489110   43360
# ...

# %%
# Mark the outliers as missing since they don’t make sense in terms of the other values in the column. 
# Turn them into NaNs

all_combined.loc[all_combined['prices'] >100, 'prices'] = np.nan

# %%
# Check the max value in 'prices'

all_combined['prices'].max()
# Out:
# 25.0

# %%
# Check Info

all_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32404859 entries, 0 to 32404858
# Data columns (total 30 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   product_id                     object
#  1   product_name                   object
#  2   aisle_id                       object
#  3   department_id                  object
#  4   prices                         float32
#  5   order_id                       object
#  6   user_id                        object
#  7   order_number                   int8
#  8   orders_day_of_week             int8
#  9   order_hour_of_day              int8
#  10  days_since_prior_order         float16
#  11  add_to_cart_order              int32
#  12  reordered                      int8
#  13  price_range_loc                object
#  14  busiest_days                   object
#  15  busiest_period_of_day          object
#  16  max_order                      int8
# ...

# %%
# change data types

# Define the dictionary with the desired data type for each column

column_datatypes = {'product_id': str, 'aisle_id': str, 'department_id': str, 'order_id' : str}

# Apply the data type changes to the specified columns

all_combined = all_combined.astype(column_datatypes)

# %%
# Checking the data types of all columns in the DataFrame

column_types = all_combined.dtypes
print(column_types)
# Out:
# product_id                        object
# product_name                      object
# aisle_id                          object
# department_id                     object
# prices                           float32
# order_id                          object
# user_id                           object
# order_number                        int8
# orders_day_of_week                  int8
# order_hour_of_day                   int8
# days_since_prior_order           float16
# add_to_cart_order                  int32
# reordered                           int8
# price_range_loc                   object
# busiest_days                      object
# busiest_period_of_day             object
# max_order                           int8
# loyalty_flag                      object
# price_average                    float32
# spending_flag                     object
# days_since_prior_order_median    float16
# frequency_flag                    object
# first_name                        object
# ...

# %%
# Exporting the merged data set ords_prods with df_customers

all_combined.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_customers_merged_cleaned.pkl'))

# %%
# Dropping unnecessary columns from 'all_combined'

all_combined = all_combined.drop(['departmend_id', 'customer_since', '_merge'], axis=1)

# %%
# Set the option to display an unlimited number of columns

pd.set_option('display.max_columns', None)

# Set the option to display an unlimited number of rows

pd.set_option('display.max_rows', None)

# %%
# Check head

all_combined.head()
# Out:
#   product_id                product_name aisle_id department_id  prices  \
# 0          1  Chocolate Sandwich Cookies       61            19     5.8
# 1          1  Chocolate Sandwich Cookies       61            19     5.8
# 2        907        Premium Sliced Bacon      106            12    20.0
# 3        907        Premium Sliced Bacon      106            12    20.0
# 4       1000                    Apricots       18            10    12.9
#
#   order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  3139998     138            28                   6                 11
# 1  1977647     138            30                   6                 17
# 2  3160996     138             1                   5                 13
# 3  2254091     138            10                   5                 14
# 4   505689     138             9                   6                 12
#
#    days_since_prior_order  add_to_cart_order  reordered     price_range_loc  \
# ...

# %%
#Rename columns for clarity

all_combined.rename(columns = {'first name' : 'first_name','last name' : 'last_name', 
                               'days_since_last_order' : 'days_since_prior_order', 
                               'price_mean': 'price_average',
                               'days_since_last_order_median' : 'days_since_prior_order_median',
                              'n_dependants': 'number_of_dependants', 'fam_status' : 'family_status'}, inplace = True)

# %%
all_combined.shape
# Out:
# (32404859, 30)

# %% [markdown]
# # Export cleaned data set

# %%
# Exporting data set

all_combined.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_customers_merged.pkl'))
